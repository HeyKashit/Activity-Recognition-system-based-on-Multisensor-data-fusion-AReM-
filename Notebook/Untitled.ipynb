# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# In this problem, we classify the activities of humans based on time series obtained by a Wireless Sensor Network. The dataset contains 7 folders that represent seven types of activities. In each folder, there are multiple files each of which represents an instant of a human performing an activity. Each file containis 6 time series collected from activities of the same person, which are called avg rss12, var rss12, avg rss13, var rss13, vg rss23, and ar rss23. There are 88 instances in the dataset, each of which contains 6 time series and each time series has 480 consecutive values

# %%
# for Bending1.
df1=pd.read_csv('bending1\dataset1.csv',skiprows=4)
df2=pd.read_csv('bending1\dataset2.csv',skiprows=4)
df3=pd.read_csv('bending1\dataset3.csv',skiprows=4)
df4=pd.read_csv('bending1\dataset4.csv',skiprows=4)
df5=pd.read_csv('bending1\dataset5.csv',skiprows=4)
df6=pd.read_csv('bending1\dataset6.csv',skiprows=4)

# now using concat function to add them and make a single dataFrame.
df_ben=pd.concat([df1,df2,df3,df4,df5,df6,df7],axis=0)

# now adding bending columns in the last as it is our y label.
df_bending1 = df_ben.assign(value ="bending1")

# now checking reuired dataframe
df_bending1
# Out:
#      # Columns: time  avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  \
# 0                  0      39.25       0.43      22.75       0.43      33.75
# 1                250      39.25       0.43      23.00       0.00      33.00
# 2                500      39.25       0.43      23.25       0.43      33.00
# 3                750      39.50       0.50      23.00       0.71      33.00
# 4               1000      39.50       0.50      24.00       0.00      33.00
# ..               ...        ...        ...        ...        ...        ...
# 475           118750      29.25       4.15      15.00       2.24      23.75
# 476           119000      42.67       2.87      16.00       2.92      19.33
# 477           119250      36.75       4.97      16.00       2.24      17.75
# 478           119500      43.67       2.36      19.00       2.83      14.75
# 479           119750      38.00       5.66      23.33       0.94      14.25
#
#      var_rss23     value
# 0         1.30  bending1
# 1         0.00  bending1
# 2         0.00  bending1
# 3         0.00  bending1
# 4         0.00  bending1
# ..         ...       ...
# 475       1.79  bending1
# 476       2.62  bending1
# 477       3.19  bending1
# 478       2.49  bending1
# 479       3.70  bending1
#
# [3360 rows x 8 columns]

# %%
# for bending2.

df1=pd.read_csv('bending2\dataset1.csv',skiprows=4)
df2=pd.read_csv('bending2\dataset2.csv',skiprows=4)
df3=pd.read_csv('bending2\dataset3.csv',skiprows=4)
df4=pd.read_csv('bending2\dataset4.csv',skiprows=4)
df5=pd.read_csv('bending2\dataset5.csv',skiprows=4)
df6=pd.read_csv('bending2\dataset6.csv',skiprows=4)

# now using concat function to add them and make a single dataFrame.
df_ben=pd.concat([df1,df2,df3,df4,df5,df6],axis=0)

# now adding bending columns in the last as it is our y label.
df_bending2 = df_ben.assign(value ="bending2")

# now checking reuired dataframe
df_bending2
# Out:
#     # Columns: time  avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  \
# 0                 0      23.75       0.43      24.00       0.00      24.67
# 1               250      22.67       0.94      24.00       0.00      24.67
# 2               500      21.33       0.47      24.00       0.00      24.75
# 3               750      21.00       0.00      24.00       0.00      25.25
# 4              1000      23.00       0.71      23.75       0.43      24.75
# ..              ...        ...        ...        ...        ...        ...
# 475          118750      27.00       0.00      14.00       0.00       6.50
# 476          119000      27.00       0.00      15.00       0.00       4.00
# 477          119250      27.00       0.00      14.25       0.83       4.00
# 478          119500      27.00       0.00      13.33       1.25       1.50
# 479          119750      26.50       0.50      15.00       0.00       3.00
#
#      var_rss23     value
# 0         0.47  bending2
# 1         0.94  bending2
# 2         0.83  bending2
# 3         1.09  bending2
# 4         0.83  bending2
# ..         ...       ...
# 475       0.50  bending2
# 476       1.00  bending2
# 477       2.00  bending2
# 478       0.50  bending2
# 479       0.00  bending2
#
# [2880 rows x 8 columns]

# %%
# for cycling

df1=pd.read_csv('cycling\dataset1.csv',skiprows=4)
df2=pd.read_csv('cycling\dataset2.csv',skiprows=4)
df3=pd.read_csv('cycling\dataset3.csv',skiprows=4)
df4=pd.read_csv('cycling\dataset4.csv',skiprows=4)
df5=pd.read_csv('cycling\dataset5.csv',skiprows=4)
df6=pd.read_csv('cycling\dataset6.csv',skiprows=4)
df7=pd.read_csv('cycling\dataset7.csv',skiprows=4)

# now using concat function to add them and make a single dataFrame.
df_ben=pd.concat([df1,df2,df3,df4,df5,df6,df7],axis=0)

# now adding bending columns in the last as it is our y label.
df_cycling = df_ben.assign(value ="cycling")

# now checking reuired dataframe
df_cycling
# Out:
#      # Columns: time  avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  \
# 0                  0      32.00       4.85      17.50       3.35      22.50
# 1                250      40.50       1.12      14.00       2.24      21.75
# 2                500      40.50       2.60      11.33       4.50      18.25
# 3                750      34.50       1.50      20.67       2.87      19.00
# 4               1000      34.50       1.50      21.25       3.27      18.25
# ..               ...        ...        ...        ...        ...        ...
# 475           118750      40.25       2.49      13.75       2.68      19.25
# 476           119000      37.00       1.22      20.50       1.50      15.25
# 477           119250      34.75       2.17      22.50       1.50      16.50
# 478           119500      34.75       5.80      21.00       2.12      16.33
# 479           119750      35.50       1.50      15.00       2.45      20.00
#
#      var_rss23    value
# 0         3.20  cycling
# 1         1.30  cycling
# 2         5.31  cycling
# 3         2.83  cycling
# 4         4.38  cycling
# ..         ...      ...
# 475       1.79  cycling
# 476       7.73  cycling
# 477       5.02  cycling
# 478       4.64  cycling
# 479       2.74  cycling
#
# [3360 rows x 8 columns]

# %%
# for lying

df1=pd.read_csv('lying\dataset1.csv',skiprows=4)
df2=pd.read_csv('lying\dataset11.csv',skiprows=4)
df3=pd.read_csv('lying\dataset8.csv',skiprows=4)
df4=pd.read_csv('lying\dataset4.csv',skiprows=4)
df5=pd.read_csv('lying\dataset13.csv',skiprows=4)
df6=pd.read_csv('lying\dataset6.csv',skiprows=4)


# now using concat function to add them and make a single dataFrame.
df_ben=pd.concat([df1,df2,df3,df4,df5,df6],axis=0)

# now adding bending columns in the last as it is our y label.
df_lying = df_ben.assign(value ="lying")

# now checking reuired dataframe
df_lying
# Out:
#      # Columns: time  avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  \
# 0                  0      29.00       0.00       9.00       0.71       8.50
# 1                250      29.00       0.00       8.00       0.71       8.50
# 2                500      29.00       0.00       8.00       0.71       8.00
# 3                750      28.50       0.50       8.25       0.43       8.75
# 4               1000      29.00       0.00       8.75       1.09       9.00
# ..               ...        ...        ...        ...        ...        ...
# 475           118750      39.50       0.50       6.75       2.49      12.75
# 476           119000      39.25       0.43       9.75       0.43      12.50
# 477           119250      39.50       0.50       9.75       0.43      12.75
# 478           119500      39.67       0.47       9.50       0.50      13.33
# 479           119750      39.50       0.50       9.00       0.00      12.67
#
#      var_rss23  value
# 0         0.50  lying
# 1         0.50  lying
# 2         1.00  lying
# 3         0.43  lying
# 4         0.00  lying
# ..         ...    ...
# 475       0.83  lying
# 476       0.50  lying
# 477       0.83  lying
# 478       0.94  lying
# 479       0.47  lying
#
# [2880 rows x 8 columns]

# %%
# for sitting

df1=pd.read_csv('sitting\dataset1.csv',skiprows=4)
df2=pd.read_csv('sitting\dataset2.csv',skiprows=4)
df3=pd.read_csv('sitting\dataset3.csv',skiprows=4)
df4=pd.read_csv('sitting\dataset4.csv',skiprows=4)
df5=pd.read_csv('sitting\dataset5.csv',skiprows=4)
df6=pd.read_csv('sitting\dataset6.csv',skiprows=4)
df7=pd.read_csv('sitting\dataset7.csv',skiprows=4)

# now using concat function to add them and make a single dataFrame.
df_ben=pd.concat([df1,df2,df3,df4,df5,df6,df7],axis=0)

# now adding bending columns in the last as it is our y label.
df_sitting = df_ben.assign(value ="sitting")

# now checking reuired dataframe
df_sitting
# Out:
#      # Columns: time  avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  \
# 0                  0      42.00       0.00      19.20       0.98      15.50
# 1                250      42.00       0.00      19.33       0.94      11.00
# 2                500      42.00       0.00      17.50       0.50      12.50
# 3                750      42.00       0.00      17.00       1.41      13.33
# 4               1000      42.00       0.00      17.50       0.87      12.00
# ..               ...        ...        ...        ...        ...        ...
# 475           118750      44.00       0.00      18.75       0.43       0.00
# 476           119000      44.25       0.43      18.75       0.43       3.00
# 477           119250      43.33       0.47      19.00       0.00       4.25
# 478           119500      44.00       0.00      18.75       0.43       4.50
# 479           119750      44.50       0.50      18.75       0.43       6.50
#
#      var_rss23    value
# 0         2.06  sitting
# 1         0.82  sitting
# 2         0.50  sitting
# 3         0.94  sitting
# 4         0.82  sitting
# ..         ...      ...
# 475       0.00  sitting
# 476       0.00  sitting
# 477       1.48  sitting
# 478       0.87  sitting
# 479       0.87  sitting
#
# [3360 rows x 8 columns]

# %%
# for standing

df1=pd.read_csv('standing\dataset1.csv',skiprows=4)
df2=pd.read_csv('standing\dataset2.csv',skiprows=4)
df3=pd.read_csv('standing\dataset3.csv',skiprows=4)
df4=pd.read_csv('standing\dataset4.csv',skiprows=4)
df5=pd.read_csv('standing\dataset5.csv',skiprows=4)
df6=pd.read_csv('standing\dataset6.csv',skiprows=4)
df7=pd.read_csv('standing\dataset7.csv',skiprows=4)

# now using concat function to add them and make a single dataFrame.
df_ben=pd.concat([df1,df2,df3,df4,df5,df6,df7],axis=0)

# now adding bending columns in the last as it is our y label.
df_standing = df_ben.assign(value ="standing")

# now checking reuired dataframe
df_standing
# Out:
#      # Columns: time  avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  \
# 0                  0       46.5        0.5      11.50       0.50      20.33
# 1                250       46.5        0.5      12.00       0.00      20.25
# 2                500       46.5        0.5      12.00       0.00      20.50
# 3                750       46.5        0.5      12.75       0.43      19.50
# 4               1000       46.5        0.5      13.25       0.43      18.75
# ..               ...        ...        ...        ...        ...        ...
# 475           118750       48.0        0.0       9.00       0.71      12.00
# 476           119000       48.0        0.0       9.75       0.83      12.00
# 477           119250       48.0        0.0       7.00       2.12      10.60
# 478           119500       48.0        0.0       0.00       0.00       7.50
# 479           119750       48.0        0.0       0.00       0.00       8.33
#
#      var_rss23     value
# 0         0.94  standing
# 1         0.43  standing
# 2         0.50  standing
# 3         0.50  standing
# 4         0.43  standing
# ..         ...       ...
# 475       0.00  standing
# 476       0.00  standing
# 477       1.36  standing
# 478       1.50  standing
# 479       2.87  standing
#
# [3360 rows x 8 columns]

# %%
# for walking

df1=pd.read_csv('walking\dataset1.csv',skiprows=4)
df2=pd.read_csv('walking\dataset2.csv',skiprows=4)
df3=pd.read_csv('walking\dataset3.csv',skiprows=4)
df4=pd.read_csv('walking\dataset4.csv',skiprows=4)
df5=pd.read_csv('walking\dataset5.csv',skiprows=4)
df6=pd.read_csv('walking\dataset6.csv',skiprows=4)
df7=pd.read_csv('walking\dataset7.csv',skiprows=4)

# now using concat function to add them and make a single dataFrame.
df_ben=pd.concat([df1,df2,df3,df4,df5,df6,df7],axis=0)

# now adding bending columns in the last as it is our y label.
df_walking = df_ben.assign(value ="walking")

# now checking reuired dataframe
df_walking
# Out:
#      # Columns: time  avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  \
# 0                  0      35.00       3.67      16.50       3.77      14.00
# 1                250      28.50       3.35      17.50       3.77      12.25
# 2                500      35.50       2.87      15.75       2.86      17.75
# 3                750      29.75      12.19      16.25       2.17      20.75
# 4               1000      27.00       2.12      16.75       0.83      24.75
# ..               ...        ...        ...        ...        ...        ...
# 475           118750      29.25       4.15      15.00       2.24      23.75
# 476           119000      42.67       2.87      16.00       2.92      19.33
# 477           119250      36.75       4.97      16.00       2.24      17.75
# 478           119500      43.67       2.36      19.00       2.83      14.75
# 479           119750      38.00       5.66      23.33       0.94      14.25
#
#      var_rss23    value
# 0         1.63  walking
# 1         3.90  walking
# 2         5.07  walking
# 3         2.59  walking
# 4         1.64  walking
# ..         ...      ...
# 475       1.79  walking
# 476       2.62  walking
# 477       3.19  walking
# 478       2.49  walking
# 479       3.70  walking
#
# [3360 rows x 8 columns]

# %%
# now making final data to work with
final_data=pd.concat([df_bending1,df_bending2,df_cycling,df_lying,df_sitting,df_standing,df_walking])
final_data
# Out:
#     # Columns: time  avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  \
# 0                 0      39.25       0.43      22.75       0.43      33.75
# 1               250      39.25       0.43      23.00       0.00      33.00
# 2               500      39.25       0.43      23.25       0.43      33.00
# 3               750      39.50       0.50      23.00       0.71      33.00
# 4              1000      39.50       0.50      24.00       0.00      33.00
# ..              ...        ...        ...        ...        ...        ...
# 475          118750      29.25       4.15      15.00       2.24      23.75
# 476          119000      42.67       2.87      16.00       2.92      19.33
# 477          119250      36.75       4.97      16.00       2.24      17.75
# 478          119500      43.67       2.36      19.00       2.83      14.75
# 479          119750      38.00       5.66      23.33       0.94      14.25
#
#      var_rss23     value
# 0         1.30  bending1
# 1         0.00  bending1
# 2         0.00  bending1
# 3         0.00  bending1
# 4         0.00  bending1
# ..         ...       ...
# 475       1.79   walking
# 476       2.62   walking
# 477       3.19   walking
# 478       2.49   walking
# 479       3.70   walking
#
# [22560 rows x 8 columns]

# %%
df = final_data.sample(frac =1)
df
# Out:
#     # Columns: time  avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  \
# 409          102250      36.75       6.06      15.00       4.12      15.00
# 56            14000      45.00       0.00      14.75       0.43      13.00
# 154           38500      39.00       0.00       2.00       0.00      16.00
# 471          117750      42.00       0.00      19.00       0.71      19.00
# 441          110250      48.00       0.00       3.00       0.00      11.25
# ..              ...        ...        ...        ...        ...        ...
# 238           59500      32.40       6.68      19.80       3.43      21.00
# 381           95250      36.00       0.00      15.00       0.00      12.25
# 146           36500      46.25       0.43      15.50       0.50      18.50
# 232           58000      33.25       1.64      11.75       3.27      19.50
# 32             8000      43.33       0.47      15.00       0.00      18.33
#
#      var_rss23     value
# 409       2.12   walking
# 56        1.00   sitting
# 154       0.71     lying
# 471       0.71  standing
# 441       0.43     lying
# ..         ...       ...
# 238       3.08   cycling
# 381       0.43  standing
# 146       0.50  standing
# 232       2.60  bending1
# 32        0.47  standing
#
# [22560 rows x 8 columns]

# %%
# now checking n unique values in the data.
df.value.unique()
# Out:
# array(['walking', 'sitting', 'lying', 'standing', 'cycling', 'bending1',
#        'bending2'], dtype=object)

# %%
df.isnull().sum()
# Out:
# # Columns: time      0
# avg_rss12          480
# var_rss12          480
# avg_rss13          480
# var_rss13          480
# avg_rss23          480
# var_rss23          480
# value                0
# dtype: int64

# %%
# dropping the null values
df1=df.dropna()
df1.shape
# Out:
# (22080, 8)

# %%
df1.isnull().sum()
# Out:
# # Columns: time    0
# avg_rss12          0
# var_rss12          0
# avg_rss13          0
# var_rss13          0
# avg_rss23          0
# var_rss23          0
# value              0
# dtype: int64

# %%
df1.describe()
df.dtypes
df1['value'] = df1['value'].map({'bending1': 1, 'bending2': 0,'lying':2,'walking':3 , 'standing': 4,'sitting':5,'cycling':6})
df1.to_csv('newdata_name.csv')
# Out:
# <ipython-input-907-7bd081f2bebf>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['value'] = df1['value'].map({'bending1': 1, 'bending2': 0,'lying':2,'walking':3 , 'standing': 4,'sitting':5,'cycling':6})

# %%
df2=df1.drop(['# Columns: time'],axis=1)
# let's see how data is distributed for every column
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in df2:
    if plotnumber<=6 :
        ax = plt.subplot(3,3,plotnumber)
        sns.distplot(df2[column])
        plt.xlabel(column,fontsize=20)
        #plt.ylabel('Salary',fontsize=20)
    plotnumber+=1
plt.show()
# Out:
# C:\Users\Owner\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Owner\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Owner\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Owner\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Owner\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Owner\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df1.drop(['# Columns: time'],axis=1,inplace=True)

# checking for the outliers


fig, ax = plt.subplots(figsize=(15,10))
sns.boxplot(data=df2, width= 0.5,ax=ax,  fliersize=3)
# Out:
# C:\Users\Owner\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# <AxesSubplot:>

# %% [markdown]
# we have a lot of outliers in the data . so, we need to remove it

# %%
q = df1['var_rss12'].quantile(0.60)
df1 = df1[df1['var_rss12']<q]

q = df1['var_rss12'].quantile(0.80)
df1 = df1[df1['var_rss12']<q]

q = df1['var_rss23'].quantile(0.70)
df1 = df1[df1['var_rss23']<q]

q = df1['avg_rss12'].quantile(0.90)
df1 = df1[df1['avg_rss12']<q]

q = df1['var_rss13'].quantile(0.90)
df1 = df1[df1['var_rss13']<q]

# %%
fig, ax = plt.subplots(figsize=(15,10))
sns.boxplot(data=df1, width= 0.5,ax=ax,  fliersize=3)
# Out:
# <AxesSubplot:>

# %%
x=df1.drop(['value'],axis=1)
y=df1['value']
x.columns
# Out:
# Index(['avg_rss12', 'var_rss12', 'avg_rss13', 'var_rss13', 'avg_rss23',
#        'var_rss23'],
#       dtype='object')

# %%
x.isnull().sum()
# Out:
# avg_rss12    0
# var_rss12    0
# avg_rss13    0
# var_rss13    0
# avg_rss23    0
# var_rss23    0
# dtype: int64

# %%
y
# Out:
# 154    2
# 471    4
# 208    5
# 458    0
# 286    2
#       ..
# 286    2
# 346    0
# 381    4
# 146    4
# 32     4
# Name: value, Length: 5278, dtype: int64

# %%
df1.shape
# Out:
# (5278, 7)

# %%
from sklearn.preprocessing import StandardScaler 
scalar = StandardScaler()
X_scaled = scalar.fit_transform(x)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["vif"] = [variance_inflation_factor(X_scaled,i) for i in range(X_scaled.shape[1])]
vif["Features"] = x.columns

#let's check the values
vif
# Out:
#         vif   Features
# 0  1.026276  avg_rss12
# 1  1.024467  var_rss12
# 2  1.326728  avg_rss13
# 3  1.026217  var_rss13
# 4  1.336752  avg_rss23
# 5  1.041395  var_rss23

# %% [markdown]
# All the VIF values are less than 5 and are very low. That means no multicollinearity. Now, we can go ahead with fitting our data to the model. Before that, let's split our data in test and training set.

# %% [markdown]
# # Splitting data into Training and Testing Set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %% [markdown]
# # 1 model using logistic regression

# %%
# making model 
from sklearn.linear_model  import  LogisticRegression
log_reg = LogisticRegression()

log_reg.fit(X_train,y_train)
# Out:
# C:\Users\Owner\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = log_reg.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,classification_report
report = classification_report(y_test, y_pred)
print(report)
print("Accuracy of the RandomForest Model is:",accuracy_score(y_test,y_pred)*100,"%")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.76      0.72       177
#            1       0.93      0.85      0.89       198
#            2       0.86      0.93      0.89       163
#            4       0.77      0.77      0.77       240
#            5       0.62      0.59      0.60       276
#            6       0.00      0.00      0.00         2
#
#     accuracy                           0.76      1056
#    macro avg       0.64      0.65      0.65      1056
# weighted avg       0.76      0.76      0.76      1056
#
# Accuracy of the RandomForest Model is: 75.9469696969697 %
# C:\Users\Owner\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Owner\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Owner\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # using 2 model

# %%
# using 2 model
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,classification_report
model=RandomForestClassifier()
model.fit(X_train,y_train)
# accuracy of RandomForest Model
y_predxgb = model.predict(X_test)
report = classification_report(y_test, y_predxgb)
print(report)
print("Accuracy of the RandomForest Model is:",accuracy_score(y_test,y_predxgb)*100,"%")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.90      0.91       177
#            1       0.90      0.94      0.92       198
#            2       0.96      0.96      0.96       163
#            4       0.83      0.87      0.85       240
#            5       0.84      0.79      0.81       276
#            6       0.00      0.00      0.00         2
#
#     accuracy                           0.88      1056
#    macro avg       0.74      0.74      0.74      1056
# weighted avg       0.88      0.88      0.88      1056
#
# Accuracy of the RandomForest Model is: 88.06818181818183 %
# C:\Users\Owner\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Owner\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Owner\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import pickle
filename='Finalmodel.sav'
pickle.dump(model,open(filename,'wb'))
